# %%
import os
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir("/content/drive/MyDrive/Harvey Associate Initiative/")

# %%
offices = pd.read_excel("2024-12-28 -- Lookup Tables.xlsx", sheet_name="Offices")
titles = pd.read_excel("2024-12-28 -- Lookup Tables.xlsx", sheet_name="Titles")

# %%
offices
# Out:
#                            Office Region
# 0                         Beijing   Asia
# 1                       Hong Kong   Asia
# 2                Resource Law LLC   Asia
# 3                        Shanghai   Asia
# 4                       Singapore   Asia
# 5                       Abu Dhabi    EME
# 6                          Astana    EME
# 7                          Athens    EME
# 8                        Brussels    EME
# 9                           Dubai    EME
# 10                      Frankfurt    EME
# 11       Global Solutions - Leeds    EME
# 12                         London    EME
# 13                         Munich    EME
# 14                          Paris    EME
# 15                         Austin   U.S.
# 16                   Century City   U.S.
# 17                        Chicago   U.S.
# 18                         Dallas   U.S.
# 19                         Denver   U.S.
# 20  Global Solutions - Pittsburgh   U.S.
# 21                        Houston   U.S.
# 22                    Los Angeles   U.S.
# 23                          Miami   U.S.
# 24                       New York   U.S.
# 25                  Orange County   U.S.
# 26                   Philadelphia   U.S.
# 27                     Pittsburgh   U.S.
# 28                      Princeton   U.S.
# 29                       Richmond   U.S.
# 30                  San Francisco   U.S.
# 31                 Silicon Valley   U.S.
# 32                         Tysons   U.S.
# 33                Washington D.C.   U.S.
# 34                     Wilmington   U.S.

# %%
titles
# Out:
#                    Title Stem     Title Group  Attorney
# 0                   Associate       Associate      True
# 1                   Law Clerk       Associate      True
# 2               New Associate       Associate      True
# 3            Seconded Trainee       Associate      True
# 4            Summer Associate       Associate      True
# 5                     Trainee       Associate      True
# 6                     Counsel         Counsel      True
# 7           Contract Attorney  Other Attorney      True
# 8        E-Discovery Attorney  Other Attorney      True
# 9            Project Attorney  Other Attorney      True
# 10    Resource Law - Attorney  Other Attorney      True
# 11           Retired Attorney  Other Attorney      True
# 12             Staff Attorney  Other Attorney      True
# 13                    Partner         Partner      True
# 14  Contract Legal Consultant      Contractor     False
# 15                 Contractor      Contractor     False
# 16  Contractor - Williams Lea      Contractor     False
# 17     Independent Contractor      Contractor     False
# 18                  Paralegal       Paralegal     False
# 19        Temporary Paralegal       Paralegal     False
# 20   Administrative Assistant           Staff     False
# 21                    Analyst           Staff     False
# 22         Assistant Director           Staff     False
# 23             Case Assistant           Staff     False
# 24                      Chief           Staff     False
# 25                      Clerk           Staff     False
# 26                Coordinator           Staff     False
# 27                   Director           Staff     False
# 28        Executive Assistant           Staff     False
# 29                     Intern           Staff     False
# 30           Legal Consultant           Staff     False
# 31            Legal Secretary           Staff     False
# 32                    Manager           Staff     False
# 33           Other Timekeeper           Staff     False
# 34               Receptionist           Staff     False
# 35       Resource Law - Staff           Staff     False
# 36            Senior Director           Staff     False
# 37             Senior Manager           Staff     False
# 38                 Specialist           Staff     False
# 39                 Supervisor           Staff     False
# 40            Temporary Staff           Staff     False

# %%
# Load the data
firm = pd.read_excel("2024-12-28 -- Firm Directory From People Finder.xlsx")

# Rename the first column to 'Email' and standardize its format
firm = firm.rename(columns={firm.columns[0]: "Email"})
firm["Email"] = firm["Email"].str.strip().str.lower()

# Filter for primary office and drop rows with missing 'Email' or 'Department'
firm = firm[firm['Office Type'] == "Primary Office"]
firm = firm.dropna(subset=['Email', 'Department'])

# Split 'Department' into 'Department' and 'Group', stripping whitespace
firm[['Department', 'Group']] = firm['Department'].str.split(' - ', n=1, expand=True)
firm['Department'] = firm['Department'].str.strip()
firm['Group'] = firm['Group'].str.strip()

# Extract the first part of 'Title' into 'Title Stem'
firm['Title Stem'] = firm['Title'].str.split('<br/>').str[0].str.strip()

firm = firm.merge(offices, on="Office", how='left')
firm = firm.merge(titles, on="Title Stem", how='left')

columns = ['Email', 'Name', 'Title', 'Title Stem', 'Title Group', 'Attorney',
           'Department', 'Group', 'Office', 'Region']

firm = firm[columns]

# Display the cleaned DataFrame
firm
# Out:
#                            Email                   Name  \
# 0        jabbeduto@reedsmith.com      Abbeduto, Jackson
# 1          eabbott@reedsmith.com           Abbott, Eric
# 2        aabboushi@reedsmith.com       Abboushi, Andrew
# 3         sabdalla@reedsmith.com         Abdalla, Safia
# 4      jabdeljaber@reedsmith.com     Abdeljaber, Jenine
# ...                          ...                    ...
# 3497      jziering@reedsmith.com          Ziering, Jake
# 3498      lzoeller@reedsmith.com           Zoeller, Lee
# 3499        bzohny@reedsmith.com       Zohny, M. Bassam
# 3500    ezourabova@reedsmith.com       Zourabova, Elina
# 3501  ueblackberry@reedsmith.com  zz - Blackberry, User
#
#                                                   Title  \
# 0                                               Counsel
# 1                                Independent Contractor
# 2     Coordinator<br/>(Global Collaboration & AV Coo...
# 3                                             Paralegal
# 4                                             Associate
# ...                                                 ...
# 3497                                          Associate
# 3498                                            Partner
# 3499                                          Associate
# 3500  Administrative Assistant<br/>(Business Develop...
# 3501                                    Temporary Staff
#
#                     Title Stem Title Group  Attorney  \
# 0                      Counsel     Counsel      True
# 1       Independent Contractor  Contractor     False
# 2                  Coordinator       Staff     False
# 3                    Paralegal   Paralegal     False
# 4                    Associate   Associate      True
# ...                        ...         ...       ...
# 3497                 Associate   Associate      True
# 3498                   Partner     Partner      True
# 3499                 Associate   Associate      True
# 3500  Administrative Assistant       Staff     False
# 3501           Temporary Staff       Staff     False
#
#                         Department                                 Group  \
# 0               Business & Finance  Entertainment & Media Industry Group
# 1               Business & Finance                Global Corporate Group
# 2           Information Technology                Information Technology
# 3                       Litigation            Global Commercial Disputes
# 4                       Litigation            Global Commercial Disputes
# ...                            ...                                   ...
# 3497                    Litigation                    Insurance Recovery
# 3498            Business & Finance                             State Tax
# 3499            Business & Finance              Financial Industry Group
# 3500  Summer Associates & Trainees          Summer Associates & Trainees
# 3501        Information Technology                Information Technology
#
#             Office Region
# 0     Century City   U.S.
# 1       Pittsburgh   U.S.
# 2       Pittsburgh   U.S.
# 3            Dubai    EME
# 4            Dubai    EME
# ...            ...    ...
# 3497       Chicago   U.S.
# 3498  Philadelphia   U.S.
# 3499     Princeton   U.S.
# 3500         Paris    EME
# 3501        London    EME
#
# [3502 rows x 10 columns]

# %%
# The firm data pulled from People Finder on Ourspace doesn't fully reflect
# Group and Department assignments for U.S. New Associates until the start of
# the calendar year following their start dates, so we patch this gap.

new_associates_mapping = pd.read_excel("2024-12-15 -- US New Associates.xlsx")
new_associates_mapping
# Out:
#           First Name           Last Name           Office          Department  \
# 0            Kayleigh           Ristuben         New York  Business & Finance
# 1        Pratik Manoj           Krishnan          Chicago  Business & Finance
# 2               Haley               Bray           Dallas  Business & Finance
# 3               Tasos   Dimitrakopoulous         New York  Business & Finance
# 4              Daniel            Morales         New York  Business & Finance
# 5              Nicole             Aguiar     Philadelphia  Business & Finance
# 17                Global Corporate Group          ehazeltine@reedsmith.com
# 18                Global Corporate Group      mschwarzberger@reedsmith.com
# 19                           Real Estate       elizabeth.lee@reedsmith.com
# 20                           Real Estate    catherine.fisher@reedsmith.com
# 21                             State Tax          eapsokardu@reedsmith.com
# 22                             State Tax               cdoig@reedsmith.com
# 23            Global Commercial Disputes              egraue@reedsmith.com
# 24            Global Commercial Disputes            klitaker@reedsmith.com
# 25            Global Commercial Disputes         eunsoo.choi@reedsmith.com
# 26            Global Commercial Disputes            dcabanay@reedsmith.com
# 27            Global Commercial Disputes            jmassian@reedsmith.com
# 28            Global Commercial Disputes          zkosnitzky@reedsmith.com
# 29            Global Commercial Disputes           tmartinez@reedsmith.com
# 30            Global Commercial Disputes               ifaiz@reedsmith.com
# 31            Global Commercial Disputes         kmulholland@reedsmith.com
# 32            Global Commercial Disputes            nspeitel@reedsmith.com
# 33            Global Commercial Disputes              gwiley@reedsmith.com
# 34            Global Commercial Disputes              bsykes@reedsmith.com
# 35         Global Regulatory Enforcement          nterezakis@reedsmith.com
# 36         Global Regulatory Enforcement            bmyrthil@reedsmith.com
# 37                    Insurance Recovery           aathenson@reedsmith.com
# 38                    Insurance Recovery               kknox@reedsmith.com
# 39                    Insurance Recovery          nordinario@reedsmith.com
# 40                    Insurance Recovery              vthorp@reedsmith.com
# 41                    Insurance Recovery      jhumphreydavis@reedsmith.com
# 42                 Intellectual Property          cmaldonado@reedsmith.com
# 43                    Labor & Employment            aworkman@reedsmith.com
# 44                    Labor & Employment              dlembo@reedsmith.com
# 45   Life Sciences Health Industry Group          vstranczek@reedsmith.com
# 46   Life Sciences Health Industry Group              cflynn@reedsmith.com
# 47   Life Sciences Health Industry Group             mhealey@reedsmith.com
# 48   Life Sciences Health Industry Group   cailin.harrington@reedsmith.com
# 49   Life Sciences Health Industry Group        aklimkiewicz@reedsmith.com
# 50   Life Sciences Health Industry Group         achronister@reedsmith.com
# 51   Life Sciences Health Industry Group               smato@reedsmith.com

# %%
firm = firm.merge(
    new_associates_mapping[['Email', 'Department', 'Group']],
    on='Email',
    how='left',
    suffixes=('', '_new')  # so we get Department_new, Group_new
)

# Update department and group only where Title Stem == "New Associate"
mask = firm['Title Stem'] == 'New Associate'
firm.loc[mask, 'Department'] = firm.loc[mask, 'Department_new']
firm.loc[mask, 'Group']      = firm.loc[mask, 'Group_new']

# Drop the extra columns
firm.drop(columns=['Department_new', 'Group_new'], inplace=True)

# %%
firm[(firm['Region'] == 'U.S.') & (firm['Title Stem'] == 'Associate')].Group.value_counts()
# Out:
# Group
# Global Commercial Disputes              81
# Global Corporate Group                  73
# Financial Industry Group                44
# Life Sciences Health Industry Group     41
# Insurance Recovery                      28
# Real Estate                             23
# Labor & Employment                      20
# Energy & Natural Resources              18
# Intellectual Property                   17
# Global Regulatory Enforcement           14
# Entertainment & Media Industry Group    14
# State Tax                               14
# Transportation Industry Group            2
# Records & E-Discovery                    1
# Name: count, dtype: int64

# %%
firm[(firm['Region'] == 'U.S.') & (firm['Title Stem'] == 'Associate')].Department.value_counts()
# Out:
# Department
# Litigation            204
# Business & Finance    186
# Name: count, dtype: int64

# %%
firm.Region.value_counts()
# Out:
# Region
# U.S.    2124
# EME     1115
# Asia     263
# Name: count, dtype: int64

# %%
firm.to_excel("firm_directory.xlsx", index=False)
